# %% [markdown]
# # 🧩 PART 1 — LIST CREATION + ACCESS + SLICING EXERCISES
#
# # 🟢 SECTION A — LIST CREATION
#
# ---
#
# ## 🔹 Exercise 1 — Empty List
#
# 1. Create an empty list using `[]`.
# 2. Create another empty list using `list()`.
# 3. Print both.
#
# ---
#
# ## 🔹 Exercise 2 — Manual Creation
#
# 1. Create a list: `["a", "b", "c"]`
# 2. Print it.
# 3. Print its length.
#
# ---
#
# ## 🔹 Exercise 3 — Create From String
#
# 1. Convert `"cat"` into a list.
# 2. Print the result.
#
# ---
#
# ## 🔹 Exercise 4 — Nested List (Matrix)
#
# 1. Create:
#
#    ```python
#    matrix = [
#        ["a", "b"],
#        ["c", "d"]
#    ]
#    ```
# 2. Print the matrix.
# 3. Print the first row.

# %%
# exe_one:
empty_list = []
houses = list()
print(empty_list)
print(houses)

# exe_two:
x= ["a", "b", "c"]
print("\n", x)
print(len(x))

# exe_three:
animal = list("cat")
print("\n", animal)
print(len(x))

# exe_four:
nested= matrix = [
    ["a", "b"],
    ["c", "d"]
]
print('\n', nested)
print(nested[0])
# Out:
# []
# []
#
#  ['a', 'b', 'c']
# 3
#
#  ['c', 'a', 't']
# 3
#
#  [['a', 'b'], ['c', 'd']]
# ['a', 'b']

# %% [markdown]
# # 🟡 SECTION B — INDEXING
#
# ---
#
# ## 🔹 Exercise 5 — Positive Index
#
# 1. Create: `["a", "b", "c"]`
# 2. Print:
#
#    * first element
#    * second element
#    * third element
#
# ---
#
# ## 🔹 Exercise 6 — Negative Index
#
# 1. Using same list:
# 2. Print:
#
#    * last element
#    * second last element
#
# ---
#
# ## 🔹 Exercise 7 — Replace Value
#
# 1. Create: `["a", "b", "c"]`
# 2. Replace `"b"` with `"x"`
# 3. Print updated list.

# %%
# exe_5
x= ["a", "b", "c"]
print(x[0])
print(x[1])
print(x[2])

print('\n')

# exe_6
x= ["a", "b", "c"]
print(x[-1])
print(x[-2])
print('\n')

# exe_7
y= ["a", "b", "c"]
y[1] = 'x'
print(y)
# Out:
# a
# b
# c
#
#
# c
# b
#
#
# ['a', 'x', 'c']

# %% [markdown]
# # 🟠 SECTION C — SLICING
#
# ---
#
# ## 🔹 Exercise 8 — Basic Slice
#
# 1. Create: `["a", "b", "c", "d"]`
# 2. Slice first two elements.
# 3. Slice last two elements.
# 4. Print both slices.
#
# ---
#
# ## 🔹 Exercise 9 — Middle Slice
#
# 1. Create: `[1, 2, 3, 4, 5]`
# 2. Slice elements from index 1 to 4.
# 3. Print result.
#
# ---
#
# ## 🔹 Exercise 10 — Skip Step
#
# 1. Create: `[0, 1, 2, 3, 4, 5]`
# 2. Slice with step 2.
# 3. Print result.

# %%
# exe_8
a = ["a", "b", "c", "d"]
print(a[:2])
print(a[2:])
print('\n')

# exe_9
b = [1, 2, 3, 4, 5]
print(b[1:4])
print('\n')

# exe_10
c = [0, 1, 2, 3, 4, 5]
print(c[0:5:2])
print(c[:5:2])
# Out:
# ['a', 'b']
# ['c', 'd']
#
#
# [2, 3, 4]
#
#
# [0, 2, 4]
# [0, 2, 4]

# %% [markdown]
# # 🔴 SECTION D — NESTED LIST ACCESS (MATRIX)
#
# ## 🔹 Exercise 11 — Access Specific Element
#
# Given:
#
# ```python
# matrix = [
#     ["a", "b", "c"],
#     ["d", "e", "f"],
#     ["g", "h", "i"]
# ]
# ```
#
# Print:
#
# * `"a"`
# * `"e"`
# * `"i"`
#
# ## 🔹 Exercise 12 — Full Row
#
# Print entire second row.
#
#
# ## 🔹 Exercise 13 — Specific Column
#
# Print:
#
# * first column
# * last column

# %%
matrix_one = [
    ["a", "b", "c"],
    ["d", "e", "f"],
    ["g", "h", "i"]
]

# exe 11
print(matrix_one[0][0])
print(matrix_one[1][1])
print(matrix_one[2][2])
print('\n')

#  exe 12
print(matrix_one[1])

#  exe 13
# print(matrix_one[0][0])
# Out:
# a
# e
# i
#
#
# ['g', 'h', 'i']

# %% [markdown]
# # 🟣 FINAL MINI CHALLENGE — MATRIX DATA PROCESSOR
#
# 1. Create a 3x3 numeric matrix.
# 2. Print:
#
#    * first row
#    * last row
#    * center element
# 3. Calculate:
#
#    * sum of first row
#    * sum of second row
# 4. Print results.

# %%
# mini challenge data processor

matrix_one = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(matrix_one[0])
print(matrix_one[2])
print(matrix_one[1][1])
print('\n')

print(sum(matrix_one[0]))
print(sum(matrix_one[1]))
# Out:
# [1, 2, 3]
# [7, 8, 9]
# 5
#
#
# 6
# 15

# %% [markdown]
# # 🟢 SET 1 — BASIC UNPACKING
#
# ## 🔹 Exercise 1 — Simple List Unpacking
#
# 1. Create a list: `[10, 20, 30]`
# 2. Unpack it into three variables.
# 3. Print each variable separately.
#
# ## 🔹 Exercise 2 — String Unpacking
#
# 1. Create a string: `"cat"`
# 2. Unpack each character into separate variables.
# 3. Print them on one line separated by spaces.
#
# ## 🔹 Exercise 3 — Tuple Unpacking
#
# 1. Create a tuple: `("John", 25, "France")`
# 2. Unpack into three variables.
# 3. Print a formatted sentence using them.
#
# ## 🔹 Exercise 4 — Unpack User Input (Split First)
#
# 1. Ask the user to enter three numbers separated by spaces.
# 2. Split the input.
# 3. Unpack into three variables.
# 4. Convert them to integers.
# 5. Print their sum.

# %%
# exe_one
list_one = [10, 20, 30]
tens, twenty, thirty = list_one
print(tens)
print(twenty)
print(thirty)
print('\n')

# exe_two
animal = "cat"
first, second, third = animal
print(first)
print(second)
print(third)
print('\n')

# exe_three
first_tuple = ("John", 25, "France")
name, age, country = first_tuple
print(f"my name is {name}, I am {age}years old and I was born in {country}")
print('\n')

# exe_four
numbers = input("write three numbers separated by spaces")
numbers = numbers.split()
print(numbers)
number1, number2, number3 = numbers
# number1, number2, number3 = numbers.split()
number1 = int(number1)
number2 = int(number2)
number3 = int(number3)
print((number1+number2+number3))
# Out:
# 10
# 20
# 30
#
#
# c
# a
# t
#
#
# my name is John, I am 25years old and I was born in France
# write three numbers separated by spaces 25 67 98
# ['25', '67', '98']
# 190

# %% [markdown]
# # 🟡 SET 2 — ASTERISK `*` (Store the Rest)
#
# ## 🔹 Exercise 5 — Capture the Middle
#
# 1. Create a list: `[1, 2, 3, 4, 5]`
# 2. Unpack:
#
#    * first value
#    * middle values (use `*`)
#    * last value
# 3. Print all three parts.
#
# ## 🔹 Exercise 6 — Ignore First, Capture Rest
#
# 1. Create a list: `["admin", "staff", "guest", "viewer"]`
# 2. Skip the first value.
# 3. Store the rest in a new list using `*`.
# 4. Print the result.
#
# ## 🔹 Exercise 7 — Only First Two
#
# 1. Create a list: `[100, 200, 300, 400, 500]`
# 2. Unpack:
#
#    * first
#    * second
#    * everything else using `*`
# 3. Print them.

# %%
list: `[1, 2, 3, 4, 5]`

list: `["admin", "staff", "guest", "viewer"]`

list: `[100, 200, 300, 400, 500]`

# %% [markdown]
# # 🟠 SET 3 — UNDERSCORE `_` (Skip Items)
#
# ---
#
# ## 🔹 Exercise 8 — Skip Middle
#
# 1. Create a list: `[10, 20, 30]`
# 2. Unpack:
#
#    * first into `a`
#    * skip second
#    * third into `c`
# 3. Print `a` and `c`.
#
# ---
#
# ## 🔹 Exercise 9 — Skip Multiple
#
# 1. Create: `[1, 2, 3, 4, 5]`
# 2. Unpack:
#
#    * first into `a`
#    * skip second and third
#    * last into `e`
# 3. Print `a` and `e`.

# %% [markdown]
# # 🔴 SET 4 — MIXED UNPACKING (Slightly Higher Level)
#
# ---
#
# ## 🔹 Exercise 10 — Nested List Unpacking
#
# 1. Create:
#
#    ```python
#    data = ["John", [90, 85, 88]]
#    ```
# 2. Unpack name and scores.
# 3. Then unpack the scores into three variables.
# 4. Print name and average score.
#
# ---
#
# ## 🔹 Exercise 11 — Swap Values
#
# 1. Create two variables: `x = 5`, `y = 10`
# 2. Swap their values using unpacking.
# 3. Print before and after.
#
# ---
#
# ## 🔹 Exercise 12 — Function Return Unpacking
#
# 1. Create a function that returns two numbers.
# 2. Call the function.
# 3. Unpack the returned values into two variables.
# 4. Print them.

# %% [markdown]
# # 🟣 MINI-CHALLENGE
#
# ## 🔹 Exercise 13 — Score Processor
#
# 1. Ask the user to enter 5 numbers separated by spaces.
# 2. Split input.
# 3. Unpack:
#
#    * first number
#    * last number
#    * everything in between using `*`
# 4. Convert all to integers.
# 5. Print:
#
#    * first
#    * last
#    * sum of middle numbers
#
# ---
#
# ---
#
# If you want:
#
# * harder unpacking (nested + conditionals)
# * unpacking inside loops
# * unpacking with dictionaries
# * combine unpacking + mini app
#
# Say the word.

# %% [markdown]
# Good.
# Exercises only. Clear. Structured. No teaching.
#
# ---
#
# # 🧩 PART 1 — REAL-WORLD DATA SIMULATION PROJECT (UNPACKING)
#
# ## 📦 PROJECT: E-COMMERCE ORDER PROCESSING SYSTEM
#
# You will simulate a small online store backend.
#
# ---
#
# ## 🎯 PROJECT RULES
#
# You are given this dataset:
#
# ```python
# orders = [
#     ("Alice", "Laptop", 1, 1200.0),
#     ("Bob", "Mouse", 2, 25.0),
#     ("Clara", "Keyboard", 1, 75.0),
#     ("David", "Monitor", 2, 300.0)
# ]
# ```
#
# Each tuple contains:
#
# ```
# (customer_name, product, quantity, price)
# ```
#
# ---
#
# ## 🛠 TASKS
#
# ### Step 1 — Loop + Unpack
#
# Loop through the orders and unpack:
#
# * customer
# * product
# * quantity
# * price
#
# ---
#
# ### Step 2 — Calculate Order Total
#
# Inside the loop:
#
# * calculate total price per order
# * print:
#
#   ```
#   Customer - Product - Total
#   ```
#
# ---
#
# ### Step 3 — Store Big Orders
#
# Create an empty list called `big_orders`.
#
# If order total > 500:
#
# * append the whole order to `big_orders`.
#
# After loop:
#
# * print `big_orders`.
#
# ---
#
# ### Step 4 — Use `*` (Asterisk Unpacking)
#
# Modify your loop to unpack like this:
#
# ```
# customer, *product_info = order
# ```
#
# Print:
#
# * customer
# * product_info
#
# ---
#
# ### Step 5 — Nested Version (Upgrade)
#
# Now change dataset to:
#
# ```python
# orders = [
#     ("Alice", ["Laptop", 1, 1200.0]),
#     ("Bob", ["Mouse", 2, 25.0]),
# ]
# ```
#
# Loop and:
#
# * unpack name
# * unpack product list
# * calculate total
# * print formatted receipt
#
# ---
#
# You are done when:
#
# * loop runs
# * unpacking works
# * totals are correct
# * no hard-coded indexing inside loop
#
# ---
