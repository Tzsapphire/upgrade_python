# %% [markdown]
# ## Pandas tutorial
# Here I learn how to use pandas to perform an ETL.
#
# In addition, I create a function that can help perform this ETL.

# %%
import pandas as pd

# %%
file = pd.read_csv('customers.csv')
file.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
file.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
customer_info = file[[ 'Index', 'First Name', 'Last Name', 'Country','Phone 1', 'Email', 'Subscription Date']]

# %%
customer_info.head()
# Out:
#    Index First Name Last Name                     Country  \
# 0      1     Sheryl    Baxter                       Chile
# 1      2    Preston    Lozano                    Djibouti
# 2      3        Roy     Berry         Antigua and Barbuda
# 3      4      Linda     Olsen          Dominican Republic
# 4      5     Joanna    Bender  Slovakia (Slovak Republic)
#
#                   Phone 1                        Email Subscription Date
# 0            229.077.5154     zunigavanessa@smith.info        2020-08-24
# 1              5153435776              vmata@colon.com        2021-04-23
# 2         +1-539-402-0259          beckycarr@hogan.com        2020-03-25
# 3  001-808-617-6467x12895  stanleyblackwell@benson.org        2020-06-02
# 4  001-234-203-0635x76146      colinalvarado@miles.net        2021-04-17

# %%
newly_subscribed = customer_info[customer_info["Subscription Date"] > '2022-01-01']

# %%
newly_subscribed.head()
# Out:
#     Index First Name Last Name     Country             Phone 1  \
# 14     15      Faith      Lutz   Singapore  (781)861-7180x8306
# 15     16    Miranda   Beasley        Oman    540.085.3135x185
# 17     18       Greg      Mata  Mozambique       (701)087-2415
# 20     21    Maxwell      Frye       Malta        423.262.3059
# 25     26     Marcus     Moody      Panama        674-677-8623
#
#                                 Email Subscription Date
# 14  cassieparrish@blevins-chapman.net        2022-01-26
# 15            vduncan@parks-hardy.com        2022-04-12
# 17            jaredjuarez@carroll.org        2022-03-26
# 20             fgibson@drake-webb.com        2022-01-12
# 25    donnamullins@norris-barrett.org        2022-05-24

# %%
newly_subscribed.count()
# Out:
# Index                19
# First Name           19
# Last Name            19
# Country              19
# Phone 1              19
# Email                19
# Subscription Date    19
# dtype: int64

# %%
newly_subscribed.to_csv('new_subscribers_2022.csv', index = False)

# %%
def get_subscribers(csv_file):
    file = pd.read_csv(csv_file)
    newly_subscribed = file[file["Subscription Date"] > '2022-01-01']
    newly_subscribed.to_csv('part_one.csv', index = False)
    print(newly_subscribed.head(2))
    return "transformation successful"

# %%
get_subscribers('customers.csv')

# %%
def extract_data(csv_file):
    file = pd.read_csv(csv_file)
    print(file.head(3))
    return "file reading successful"

# %%
def transform(file):
    print("getting newly subscribed customers since 2022")
    newly_subscribed = file[file["Subscription Date"] > '2022-01-01']
    print(newly_subscribed.head(3))
    return "transformation successful"

# %%
def load_data(newly_subscribed):
    file_name = input("whats your output file name?: ")
    if '/' in file_name or '\\' in file_name:
        print("Invalid characters like / or \ in file_name")
    else:    
    newly_subscribed.to_csv(f'{file_name}.csv', index = False)
    return "file successfully stored as csv"

# %%
def extract_data()
def transform()
def load_data()
# Out:
#   Cell In[47], line 1
#     def extract_data()
#                       ^
# SyntaxError: expected ':'

# %%
def get_amount(amount):
    total = amount * 10
    return total

# %%
def pay_amount(name, total):
    print(f"pay {name} a total of {total} amount ")

# %%
pe = get_amount(5)
pay_amount( "pelebe",pe)
# Out:
# pay pelebe a total of 50 amount

# %%
url = 'https://agents-for-data-prod-tmp.8e464e4039ccd5897a90175399bb04a7.r2.cloudflarestorage.com/2026-03-07/890bb71b-a430-4345-9a41-d17dbc2e4736/flights-1m.json?X-Amz-Expires=3600&X-Amz-Date=20260307T105500Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=7283c8cfa964ae1d21c994a61ac3c987%2F20260307%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=5cc47c80a7b9164a943bab8480f54a24ac4511d51365cb79a465841434257168'

# %%
flight_data = pd.read_json(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 flight_data = pd.read_json(url)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
# ...

# %%
flight_data = pd.read_json(url, lines=True,  chunksize=1000,  nrows=5000)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 flight_data = pd.read_json(url, lines=True, nrows=5000)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
# ...

# %%
filenames = "flights.json"
url = "https://agents-for-data-prod-tmp.8e464e4039ccd5897a90175399bb04a7.r2.cloudflarestorage.com/2026-03-11/e91cc59f-f079-4166-92ab-0a80055e0705/flights-1m.json?X-Amz-Expires=3600&X-Amz-Date=20260311T115041Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=7283c8cfa964ae1d21c994a61ac3c987%2F20260311%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=d4dd82e5048274ddfb492920b554db4cdcbc8d8abc2d5c23d1b60f2f6480c5a2"

# %%
import requests
import json

# url = "https://api.example.com/data.json"

# 1. Fetch the data
response = requests.get(url)

# 2. Check if the request was successful
if response.status_code == 200:
    data = response.json()  # This parses the JSON automatically
    
    # 3. Save to a local file
    with open("flights.json", "w") as f:
        json.dump(data, f, indent=4)
    print("Download complete!")
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# Download complete!

# %%
import pandas as pd
import json

# Load your JSON data (from the file we saved earlier)
with open('flights.json', 'r') as f:
    data = json.load(f)

# Convert to a DataFrame
# If your JSON is a simple list of dictionaries, this works perfectly:
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('data_flights.csv', index=False)

print("Conversion successful! 'data.csv' is ready for analysis.")
# Out:
# Conversion successful! 'data.csv' is ready for analysis.

# %%
file_csv = pd.read_csv("data_flights.csv")

# %%
file_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   FL_DATE    1000000 non-null  object
#  1   DEP_DELAY  1000000 non-null  int64
#  2   ARR_DELAY  1000000 non-null  int64
#  3   AIR_TIME   1000000 non-null  int64
#  4   DISTANCE   1000000 non-null  int64
#  5   DEP_TIME   1000000 non-null  float64
#  6   ARR_TIME   1000000 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 53.4+ MB

# %%
file_csv.head()
# Out:
#       FL_DATE  DEP_DELAY  ARR_DELAY  AIR_TIME  DISTANCE   DEP_TIME   ARR_TIME
# 0  2006-01-01          5         19       350      2475   9.083333  12.483334
# 1  2006-01-02        167        216       343      2475  11.783334  15.766666
# 2  2006-01-03         -7         -2       344      2475   8.883333  12.133333
# 3  2006-01-04         -5        -13       331      2475   8.916667  11.950000
# 4  2006-01-05         -3        -17       321      2475   8.950000  11.883333

# %%
import pandas as pd

# 1. Load your JSON (or CSV)
df = pd.read_json('flights.json')

# 2. Optimization: Ensure date columns are actual datetime objects
# This makes Parquet much more efficient for time-series analysis
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])

# 3. Export to Parquet
df.to_parquet('flights_data.parquet', engine='pyarrow', compression='snappy')

print("Conversion to Parquet complete!")
# Out:
# Conversion to Parquet complete!

# %%
That looks like a classic flight delay dataset! You have a great mix of time-series data (`FL_DATE`), numerical performance metrics (`DEP_DELAY`, `ARR_DELAY`), and logistical info (`DISTANCE`, `AIR_TIME`).

Since you are already in a notebook environment, here are four project ideas ranging from beginner to advanced:

---

### 1. Delay Propensity Analysis (The "When Should I Fly?" Project)

Analyze which dates or times of day are most prone to delays.

* **Goal:** Determine if flying early in the morning actually reduces your chance of a 15+ minute delay.
* **Action:** Create a "Delay Binary" column (1 if `DEP_DELAY > 0`, 0 otherwise) and group by `DEP_TIME` (rounded to the hour) to see the probability of a late departure.
* **Visualization:** A bar chart showing average `DEP_DELAY` per day of the week.

### 2. The "Speed Demon" Investigation (Flight Efficiency)

Do pilots "make up time" in the air when they leave the gate late?

* **Goal:** See if there is a correlation between `DEP_DELAY` and `AIR_TIME`.
* **Action:** Calculate the "Air Speed" ($Speed = Distance / AirTime$). Compare the speed of flights that departed late versus those that departed on time.
* **Math:** You can use a simple correlation coefficient:

$$r = \frac{\sum(x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum(x_i - \bar{x})^2 \sum(y_i - \bar{y})^2}}$$



### 3. Arrival Delay Prediction (Machine Learning)

Predict the `ARR_DELAY` based on the other features.

* **Goal:** Build a regression model that can predict how late a plane will arrive given its departure delay and distance.
* **Action:** Use Scikit-Learn to train a **Linear Regression** or **Random Forest** model.
* **Key Feature:** `DEP_DELAY` will likely be your strongest predictor, but `DISTANCE` and `DEP_TIME` (time of day) often add interesting nuances.

### 4. Data Cleaning & Feature Engineering (The "Pro" Workflow)

Notice those `DEP_TIME` values like `9.083333`? Those look like they’ve been converted to decimal hours.

* **Goal:** Clean the data for better readability.
* **Action:** Convert those decimal times back into standard `HH:MM` format.
* **Analysis:** Calculate "Taxi Time" if you had gate times, or simply create a "Season" feature from the `FL_DATE` to see if winter weather significantly impacts the `ARR_DELAY` more than summer.

---

### Which one sounds most interesting?

I can help you write the code for any of these. For example, **would you like to see how to calculate which day of the week has the highest average delays?**
